# %% [markdown]
# # Comparing Cost Functions
#
# In this notebook, we take a look at the different fitting cost functions offered in PyBOP. Cost functions for fitting problems conventionally describe the distance between two points (the target and the prediction) which is to be minimised via PyBOP's optimisation algorithms.
#
# ### Setting up the Environment
#
# If you don't already have PyBOP installed, check out the [installation guide](https://pybop-docs.readthedocs.io/en/latest/installation.html) first.
#
# We begin by importing the necessary libraries. Let's also fix the random seed to generate consistent output during development.

# %%
import numpy as np
import pybamm

import pybop

pybop.plot.use_backend("plotly")
go = pybop.plot.backends.PlotlyManager().go
pybop.plot.backends.PlotlyManager().pio.renderers.default = "notebook_connected"

np.random.seed(8)  # users can remove this line

# %% [markdown]
# For this notebook, we need to construct parameters, a model and a simulator before we can compare differing cost functions. This an arbitrary selection.

# %%
model = pybamm.lithium_ion.SPM()
parameter_values = pybamm.ParameterValues("Chen2020")

# %% [markdown]
# Next, as we will need reference data to compare our model predictions to (via the cost function), we will create synthetic data from the model constructed above.

# %%
t_eval = np.arange(0, 300, 20)
solution = pybamm.Simulation(model, parameter_values=parameter_values).solve(
    t_eval=t_eval, t_interp=t_eval
)
dataset = pybop.import_pybamm_solution(solution)

# %% [markdown]
# Now, we can construct parameters and bring this all together in the simulator class.

# %%
parameter_values.update(
    {
        "Positive electrode thickness [m]": pybop.Parameter(
            pybop.Gaussian(7.56e-05, 0.5e-05, truncated_at=[65e-06, 10e-05]),
        ),
        "Positive particle radius [m]": pybop.Parameter(
            pybop.Gaussian(5.22e-06, 0.5e-06, truncated_at=[2e-06, 9e-06]),
        ),
    }
)
simulator = pybop.pybamm.Simulator(
    model,
    parameter_values=parameter_values,
    protocol=dataset,
    output_variables=["Voltage [V]"],
)

# %% [markdown]
# We can now generate a solution for some candidate parameter values.

# %%
inputs = simulator.parameters.to_dict([7.56e-05, 5.22e-06])
solution = simulator.solve(inputs)

# %% [markdown]
# ## Sum of squared errors and root mean squared error
#
# First, let's start with two commonly-used cost functions: the sum of squared errors (SSE) and the root mean squared error (RMSE). Constructing these classes is very concise in PyBOP, and only requires the dataset.

# %%
SSE = pybop.SumSquaredError(dataset)
RMSE = pybop.RootMeanSquaredError(dataset)

# %% [markdown]
# Now, we can investigate how these functions differ for the same dataset and inputs. To acquire the cost value for each cost function, we can use the `evaluate` method of the constructed cost class.

# %%
SSE_value = SSE.evaluate(solution, inputs).get_values()
RMSE_value = RMSE.evaluate(solution, inputs).get_values()
print(SSE_value, RMSE_value)
# Out:
# [3.30221688e-09] [1.48373782e-05]

# %% [markdown]
# We can also generate a random sample of candidate solutions from the parameters, if the parameters have a prior distribution from which to sample.

# %%
samples = simulator.parameters.sample_from_distribution(2)
print("Samples:", samples)
inputs = [simulator.parameters.to_dict(s) for s in samples]
solution = simulator.solve(inputs)
print("SSE costs:", SSE.evaluate(solution, inputs).get_values())
print("RMSE costs:", RMSE.evaluate(solution, inputs).get_values())
# Out:
# Samples: [[8.13658824e-05 5.78129588e-06]
#  [8.49368515e-05 5.25871051e-06]]
# SSE costs: [1.15262672e-05 8.50813826e-04]
# RMSE costs: [0.00087659 0.00753133]

# %% [markdown]
# ### Comparing RMSE and SSE
#
# Now, let's vary one of the parameters, and keep a fixed value for the other, to create a plot comparing the cost values for the RMSE and SSE functions.

# %%
x_range = np.linspace(4.72e-06, 5.72e-06, 25)
inputs = [simulator.parameters.to_dict([7.56e-05, i]) for i in x_range]
solution = simulator.solve(inputs)
y_SSE = SSE.evaluate(solution, inputs).get_values()
y_RMSE = RMSE.evaluate(solution, inputs).get_values()

fig = go.Figure()
fig.add_trace(go.Scatter(x=x_range, y=y_SSE, mode="lines", name="SSE"))
fig.add_trace(go.Scatter(x=x_range, y=y_RMSE, mode="lines", name="RMSE"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="2e9a7caf-2b3f-4b60-b045-921818948e34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2e9a7caf-2b3f-4b60-b045-921818948e34")) {                    Plotly.newPlot(                        "2e9a7caf-2b3f-4b60-b045-921818948e34",                        [{"mode":"lines","name":"SSE","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.0005096760915314286,0.0004326152350089508,0.0003611625732620625,0.00029551415344891805,0.00023587032242913548,0.00018243529238081465,0.00013541670765644046,9.502521390541155e-05,6.147403044923691e-05,3.497852685753399e-05,1.5755804630227638e-05,4.0242848483130065e-06,3.3026101740368053e-09,3.912709023950487e-06,1.5972481478783237e-05,3.640234286944698e-05,6.542139039917507e-05,0.0001032477345370953,0.00015009814865592826,0.00020618772982807927,0.00027172957120480173,0.0003469344463634513,0.0004320105059458592,0.0005271629868810702,0.0006325939344242302],"type":"scatter"},{"mode":"lines","name":"RMSE","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.005829099939278382,0.005370383195570256,0.004906883418641358,0.004438574496756949,0.0039654366924643195,0.003487456497992146,0.003004626517627335,0.002516945422602717,0.0020244181130922028,0.0015270565773743505,0.0010248838838368517,0.0005179629876296186,1.4838261744640228e-05,0.0005107320904969314,0.0010319070203199264,0.0015578263247111766,0.0020884027453084023,0.002623581960311707,0.0031633120686597694,0.0037075394340728577,0.0042562077894514015,0.004809258060334957,0.005366628401183616,0.005928254306741967,0.006494068752455224],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444 ...

# %% [markdown]
# In this situation, it's clear that the curvature of the SSE cost is greater than that of the RMSE. This can improve the rate of convergence for certain optimisation algorithms. However, with incorrect hyperparameter values, larger gradients can also result in the algorithm not converging due to sampling locations outside of the "cost valley", e.g. infeasible parameter values.
#
# ## Minkowski distance
#
# Next, let's investigate the Minkowski distance. The Minkowski cost takes a general form, which allows for hyperparameter calibration on the cost function itself, given by
#
# $\mathcal{L_p} = \displaystyle \Big(\sum_i  |\hat{y_i}-y_i|^p\Big)^{1/p}$
#
# where $p ≥ 0$ is the order of the Minkowski distance.
#
# For $p = 1$, it is the Manhattan distance.
# For $p = 2$, it is the Euclidean distance.
# For $p ≥ 1$, the Minkowski distance is a metric, but for $0<p<1$, note that the Minkowski distance is not a metric because the triangle inequality does not hold [[1]](https://en.wikipedia.org/wiki/Minkowski_distance), [[2]](https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.distance.minkowski.html#scipy.spatial.distance.minkowski).
#
# The Minkowski distance is related to the previous two cost function as follows. The RMSE can be computed by dividing the Euclidean distance by the square root of the length of the target vector, while the SSE is the square of the Euclidean distance.
#
# PyBOP offers a Minkowski class, which we will construct below. This class has an optional argument of `p` which designates the order in the above equation. This value can be a float, with the only requirement that it is not negative. First, let's confirm the relationship between the SSE, RMSE and the Minkowski distance with a `p` value of 2.

# %%
minkowski = pybop.Minkowski(dataset, p=2)
y_minkowski = minkowski.evaluate(solution, inputs).get_values()

fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=x_range,
        y=np.asarray(y_RMSE) * np.sqrt(len(t_eval)),
        mode="lines",
        name="RMSE*N",
    )
)
fig.add_trace(
    go.Scatter(
        x=x_range,
        y=np.sqrt(y_SSE),
        mode="lines",
        line=dict(dash="dash"),
        name="sqrt(SSE)",
    )
)
fig.add_trace(
    go.Scatter(
        x=x_range, y=y_minkowski, mode="lines", line=dict(dash="dot"), name="Minkowski"
    )
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="91518b3a-b2fb-45f3-a8ce-c0f35321ba19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("91518b3a-b2fb-45f3-a8ce-c0f35321ba19")) {                    Plotly.newPlot(                        "91518b3a-b2fb-45f3-a8ce-c0f35321ba19",                        [{"mode":"lines","name":"RMSE*N","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":{"dtype":"f8","bdata":"IiHBLioelz+OYH5rcEyVPwUB5H3bdZM\u002fpy+KnGSakT9ipFNMDXSPPzrt+i98qYs\u002fO5HbCxLVhz+CSiIvzvaDP1Tr5SWzDoA\u002f\u002fDH5Vo45eD9PzG97LEJwP6pUUlkEb2A\u002faSf1JUUhDj9gWJ0zSTRgP86V6w6yXnA\u002fSe9s\u002fIO2eD8dG0jVn5CAP+ZVz09Wz4Q\u002fGmEUc0oXiT88kHVdYGiNP4pgnGc94ZA\u002fgY6Gib0Skz\u002fijG+BoEiVP4IpVYvVgpc\u002fio6UO0vBmT8="},"type":"scatter"},{"line":{"dash":"dash"},"mode":"lines","name":"sqrt(SSE)","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":{"dtype":"f8","bdata":"IiHBLioelz+NYH5rcEyVPwUB5H3bdZM\u002fpy+KnGSakT9ipFNMDXSPPzrt+i98qYs\u002fOpHbCxLVhz+BSiIvzvaDP1Tr5SWzDoA\u002f\u002fDH5Vo45eD9PzG97LEJwP6pUUlkEb2A\u002faSf1JUUhDj9hWJ0zSTRgP86V6w6yXnA\u002fSe9s\u002fIO2eD8dG0jVn5CAP+VVz09Wz4Q\u002fGmEUc0oXiT87kHVdYGiNP4pgnGc94ZA\u002fgY6Gib0Skz\u002fijG+BoEiVP4IpVYvVgpc\u002fiY6UO0vBmT8="},"type":"scatter"},{"line":{"dash":"dot"},"mode":"lines","name":"Minkowski","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.02257600698820384,0.020799404679195766,0.019004277762179295,0.017190525106840628,0.015358070270354133,0.013506860937346422,0.011636868464343853,0.009748087705053312,0.007840537637766744,0.0059142646928873575,0.003969358213896503,0.0020060620250413512,5.746834062365822e-05,0.001978056880868315,0.003996558704533594,0.006033435411889895,0.008088349052753291,0.01016108923969745,0.012251454960776221,0.014359238483571448,0.01648422188654356,0.018626176375291074,0.02078486242306788,0.022960030202094035,0.025151420127385058],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111 ...

# %% [markdown]
# As expected, these lines lie on top of one another. Now, let's take a look at how the Minkowski cost changes for different orders, `p`.

# %%
p_orders = np.append(0.75, np.linspace(1, 3, 3))
y_minkowski_p = []
for p in p_orders:
    minkowski_p = pybop.Minkowski(dataset, p=p)
    y_minkowski_p.append(minkowski_p.evaluate(solution, inputs).get_values())

fig = go.Figure()
for i, p in enumerate(p_orders):
    fig.add_trace(
        go.Scatter(x=x_range, y=y_minkowski_p[i], mode="lines", name=f"Minkowski {p}")
    )
fig.update_yaxes(range=[0, np.max(y_minkowski_p[2])])
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="730b21e7-9c35-41ea-8cf8-3244b3d55b4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("730b21e7-9c35-41ea-8cf8-3244b3d55b4e")) {                    Plotly.newPlot(                        "730b21e7-9c35-41ea-8cf8-3244b3d55b4e",                        [{"mode":"lines","name":"Minkowski 0.75","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.18486964454534802,0.17001964479155815,0.1550769877162036,0.1400400745351709,0.12490744197767185,0.10967775963917872,0.09434982675636346,0.07892256778035119,0.06339502486424109,0.04776634040031154,0.0320356958334903,0.01620191333997352,0.00030436854976606206,0.01576659406241885,0.031909845077347475,0.04815563266212029,0.06450471158635138,0.08095714585486698,0.0975128072722682,0.114171446213863,0.1309327113119728,0.14779615801157506,0.1647612538203707,0.1818273823620954,0.19899384692597602],"type":"scatter"},{"mode":"lines","name":"Minkowski 1.0","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.07748078433229466,0.07128692103336931,0.06504855505624896,0.05876504344271627,0.052435806466465174,0.046060326541294216,0.03963814706891178,0.033168871232363006,0.026652160740123776,0.020087734525076062,0.013475367404256033,0.0068148887029328975,0.000140508227298497,0.006650822066178286,0.013456135732639929,0.020309727108233755,0.02721151590304416,0.03416137608266556,0.041159137378347754,0.04820458680264528,0.05529747016687381,0.06243749359854078,0.0696243250548303,0.07685759583064167,0.08413690205845858],"type":"scatter"},{"mode":"lines","name":"Minkowski 2.0","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.02257600698820384,0.020799404679195766,0.019004277762179295,0.017190525106840628,0.015358070270354133,0.013506860937346422,0.011636868464343853,0.009748087705053312,0.007840537637766744,0.0059142646928873575,0.003969358213896503,0.0020060620250413512,5.746834062365822e-05,0.001978056880868315,0.003996558704533594,0.006033435411889895,0.008088349052753291,0.01016108923969745,0.012251454960776221,0.014359238483571448,0.01648422188654356,0.018626176375291074,0.02078486242306788,0.022960030202094035,0.025151420127385058],"type":"scatter"},{"mode":"lines","name":"Minkowski 3.0","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.01587707580684506,0.014638398616671494,0.013384357333695031,0.012114976352710713,0.010830298370596412,0.009530383713803395,0.008215309754451415,0.00688517053955692,0.005540077003628456,0.004180159123739155,0.0028055768597803734,0.0014166025169372349,5.012849282796664e-05,0.0014057959338190347,0.002837444402993131,0.004283090213435272,0.0057424177005926 ...

# %% [markdown]
# As seen above, the Minkowski cost allows for a range of different cost functions to be created. This provides users with another hyperparameter to calibrate for optimisation algorithm convergence. This addition does expand the global search space, and should be carefully considered before deciding upon.
#
# ## Sum of power
#
# Next, we introduce a similar cost function, the `SumOfPower` implementation. This cost function is the $p$-th power of the Minkowski distance of order $p$. It provides a generalised formulation for the Sum of Squared Errors (SSE) cost function, and is given by,
#
# $\mathcal{L_p} = \displaystyle \sum_i  |\hat{y_i}-y_i|^p$
#
# where $p ≥ 0$ is the power order. A few special cases include,
#
# $p = 1$: Sum of Absolute Differences
# $p = 2$: Sum of Squared Differences
#
# Next we repeat the above examples with the `SumOfPower` class.

# %%
sumofpower = pybop.SumOfPower(dataset, p=2)
y_sumofpower = sumofpower.evaluate(solution, inputs).get_values()

fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=x_range,
        y=np.asarray(y_RMSE) * np.sqrt(len(t_eval)),
        mode="lines",
        name="RMSE*N",
    )
)
fig.add_trace(
    go.Scatter(
        x=x_range,
        y=y_SSE,
        mode="lines",
        line=dict(dash="dash"),
        name="SSE",
    )
)
fig.add_trace(
    go.Scatter(
        x=x_range,
        y=y_sumofpower,
        mode="lines",
        line=dict(dash="dot"),
        name="Sum of Power",
    )
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="fa9967eb-2048-42c5-855f-5d7c649ea666" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fa9967eb-2048-42c5-855f-5d7c649ea666")) {                    Plotly.newPlot(                        "fa9967eb-2048-42c5-855f-5d7c649ea666",                        [{"mode":"lines","name":"RMSE*N","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":{"dtype":"f8","bdata":"IiHBLioelz+OYH5rcEyVPwUB5H3bdZM\u002fpy+KnGSakT9ipFNMDXSPPzrt+i98qYs\u002fO5HbCxLVhz+CSiIvzvaDP1Tr5SWzDoA\u002f\u002fDH5Vo45eD9PzG97LEJwP6pUUlkEb2A\u002faSf1JUUhDj9gWJ0zSTRgP86V6w6yXnA\u002fSe9s\u002fIO2eD8dG0jVn5CAP+ZVz09Wz4Q\u002fGmEUc0oXiT88kHVdYGiNP4pgnGc94ZA\u002fgY6Gib0Skz\u002fijG+BoEiVP4IpVYvVgpc\u002fio6UO0vBmT8="},"type":"scatter"},{"line":{"dash":"dash"},"mode":"lines","name":"SSE","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.0005096760915314286,0.0004326152350089508,0.0003611625732620625,0.00029551415344891805,0.00023587032242913548,0.00018243529238081465,0.00013541670765644046,9.502521390541155e-05,6.147403044923691e-05,3.497852685753399e-05,1.5755804630227638e-05,4.0242848483130065e-06,3.3026101740368053e-09,3.912709023950487e-06,1.5972481478783237e-05,3.640234286944698e-05,6.542139039917507e-05,0.0001032477345370953,0.00015009814865592826,0.00020618772982807927,0.00027172957120480173,0.0003469344463634513,0.0004320105059458592,0.0005271629868810702,0.0006325939344242302],"type":"scatter"},{"line":{"dash":"dot"},"mode":"lines","name":"Sum of Power","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.0005096760915314286,0.0004326152350089508,0.0003611625732620625,0.00029551415344891805,0.00023587032242913548,0.00018243529238081465,0.00013541670765644046,9.502521390541155e-05,6.147403044923691e-05,3.497852685753399e-05,1.5755804630227638e-05,4.0242848483130065e-06,3.3026101740368053e-09,3.912709023950487e-06,1.5972481478783237e-05,3.640234286944698e-05,6.542139039917507e-05,0.0001032477345370953,0.00015009814865592826,0.00020618772982807927,0.00027172957120480173,0.0003469344463634513,0.0004320105059458592,0.0005271629868810702,0.0006325939344242302],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5 ...

# %% [markdown]
# As expected, the `SumOfPower` with order `p=2` equates to the `SSE` implementation. Next, we compare the `Minkowski` to the `SumOfPower`,

# %%
p_orders = np.asarray([0.75, 2])
y_minkowski_p = []
y_sumofpower_p = []
for p in p_orders:
    minkowski_p = pybop.Minkowski(dataset, p=p)
    y_minkowski_p.append(minkowski_p.evaluate(solution, inputs).get_values())

    sumofpower_p = pybop.SumOfPower(dataset, p=p)
    y_sumofpower_p.append(sumofpower_p.evaluate(solution, inputs).get_values())

fig = go.Figure()
for i, p in enumerate(p_orders):
    fig.add_trace(
        go.Scatter(x=x_range, y=y_minkowski_p[i], mode="lines", name=f"Minkowski {p}")
    )
    fig.add_trace(
        go.Scatter(
            x=x_range,
            y=y_sumofpower_p[i],
            mode="lines",
            line=dict(dash="dash"),
            name=f"Sum of Power {p}",
        )
    )
fig.update_yaxes(range=[0, 0.3])
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="541425b9-9723-4824-b684-5def9befbec4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("541425b9-9723-4824-b684-5def9befbec4")) {                    Plotly.newPlot(                        "541425b9-9723-4824-b684-5def9befbec4",                        [{"mode":"lines","name":"Minkowski 0.75","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.18486964454534802,0.17001964479155815,0.1550769877162036,0.1400400745351709,0.12490744197767185,0.10967775963917872,0.09434982675636346,0.07892256778035119,0.06339502486424109,0.04776634040031154,0.0320356958334903,0.01620191333997352,0.00030436854976606206,0.01576659406241885,0.031909845077347475,0.04815563266212029,0.06450471158635138,0.08095714585486698,0.0975128072722682,0.114171446213863,0.1309327113119728,0.14779615801157506,0.1647612538203707,0.1818273823620954,0.19899384692597602],"type":"scatter"},{"line":{"dash":"dash"},"mode":"lines","name":"Sum of Power 0.75","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.28193513710668405,0.26477338540547685,0.24712149200336642,0.2289229058032181,0.21010734544040163,0.1905850928145752,0.17023773417455698,0.1489021282276071,0.1263401483129375,0.10217425433854606,0.07572261808887815,0.045412428666132786,0.002304357364481973,0.04449420122672969,0.07549940373798425,0.10279815490523926,0.12799516905937375,0.1517719071743181,0.17450032677162236,0.19641204920101288,0.21766375691456127,0.2383676739133053,0.2586076192562668,0.27844823214078185,0.29794063282566563],"type":"scatter"},{"mode":"lines","name":"Minkowski 2.0","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.02257600698820384,0.020799404679195766,0.019004277762179295,0.017190525106840628,0.015358070270354133,0.013506860937346422,0.011636868464343853,0.009748087705053312,0.007840537637766744,0.0059142646928873575,0.003969358213896503,0.0020060620250413512,5.746834062365822e-05,0.001978056880868315,0.003996558704533594,0.006033435411889895,0.008088349052753291,0.01016108923969745,0.012251454960776221,0.014359238483571448,0.01648422188654356,0.018626176375291074,0.02078486242306788,0.022960030202094035,0.025151420127385058],"type":"scatter"},{"line":{"dash":"dash"},"mode":"lines","name":"Sum of Power 2.0","x":{"dtype":"f8","bdata":"RcGEuA\u002fM0z5ppob3zPjTPo2LiDaKJdQ+snCKdUdS1D7WVYy0BH\u002fUPvo6jvPBq9Q+HiCQMn\u002fY1D5CBZJxPAXVPmbqk7D5MdU+is+V77Ze1T6vtJcudIvVPtOZmW0xuNU+936brO7k1T4bZJ3rqxHWPj9JnyppPtY+ZC6haSZr1j6IE6Oo45fWPqz4pOegxNY+0N2mJl7x1j70wqhlGx7XPhioqqTYStc+PI2s45V31z5hcq4iU6TXPoVXsGEQ0dc+qTyyoM391z4="},"y":[0.0005096760915314286,0.0004326152350089508,0.0003611625732620625,0.00029551415344891805,0.00023587032242913548,0.00018243529238081465,0.00013541670765644046,9.502521390541155e-05,6.147403044923691e-05,3.497852685753399e-05,1.5755804630227638e-05,4.0242848483130065e-06,3.3026101740368053e-09,3.912709023950487e-06,1.597 ...

# %% [markdown]
# The figure demonstrates the distinct behaviour of the `Minkowski` distance and the `SumOfPower` function. One notable difference is the effect of the `1/p` exponent in the `Minkowski` distance, which has a linearising impact on the response. This linearisation can enhance the robustness of certain optimisation algorithms, potentially making them less sensitive to outliers or extreme values. However, this increased robustness may come at the cost of a slower convergence rate, as the linearised response might require more iterations to reach the optimal solution. In contrast, the `SumOfPower` function does not exhibit this linearising effect, which can lead to faster convergence in some cases but may be more susceptible to the influence of outliers or extreme values.
#
# ## Concluding thoughts
#
# In this notebook, we've shown the different fitting cost functions offered in PyBOP. Selection between these functions can affect the optimisation result in the case that the optimiser hyperparameter values are not properly calibrated.
