# %% [markdown]
# # Hyperparameter Tuning
#
# ## Calibrating the learning rate of the Gradient Descent optimiser
#
# In this notebook, we calibrate the learning rate for the gradient descent optimiser on a parameter identification problem.
#
# ### Setting up the Environment
#
# If you don't already have PyBOP installed, check out the [installation guide](https://pybop-docs.readthedocs.io/en/latest/installation.html) first.
#
# We begin by importing the necessary libraries. Let's also fix the random seed to generate consistent output during development.

# %%
import numpy as np
import pybamm

import pybop

pybop.plot.PlotlyManager().pio.renderers.default = "notebook_connected"

np.random.seed(8)  # users can remove this line

# %% [markdown]
# ## Generating a synthetic dataset
#
# To demonstrate parameter estimation, we first need some data. We will generate synthetic data using the single particle model (SPM) as the forward model, which requires defining the parameter values and the model itself.

# %%
model = pybamm.lithium_ion.SPM()
parameter_values = pybamm.ParameterValues("Chen2020")
parameter_values.update(
    {
        "Negative electrode active material volume fraction": 0.65,
        "Positive electrode active material volume fraction": 0.51,
    }
)
parameter_values.set_initial_state(0.4)
experiment = pybamm.Experiment(
    [
        "Discharge at 0.5C for 6 minutes (5 second period)",
        "Charge at 0.5C for 6 minutes (5 second period)",
    ]
    * 2
)
solution = pybamm.Simulation(
    model, parameter_values=parameter_values, experiment=experiment
).solve()

# %% [markdown]
# To make the parameter estimation more realistic, we add Gaussian noise to the data. The dataset for optimisation is composed of time, current, and the noisy voltage data:

# %%
sigma = 0.002  # 2 mV
corrupt_values = solution["Voltage [V]"].data + np.random.normal(
    0, sigma, len(solution.t)
)
dataset = pybop.Dataset(
    {
        "Time [s]": solution.t,
        "Current function [A]": solution["Current [A]"].data,
        "Voltage [V]": corrupt_values,
    }
)

# %% [markdown]
# ## Identifying the parameters
#
# We select the parameters for estimation and set up their prior distributions and bounds:

# %%
parameters = {
    "Negative electrode active material volume fraction": pybop.Parameter(
        initial_value=0.5,
    ),
    "Positive electrode active material volume fraction": pybop.Parameter(
        initial_value=0.5,
    ),
}
true_values = [parameter_values[p] for p in parameters.keys()]
parameter_values.update(parameters)

# %% [markdown]
# ### Setting up the problem with an unsuitable sigma value
#
# With the datasets and parameters defined, we can set up the optimisation problem, its cost function, and the optimiser. Let's begin by setting the learning rate (`eta`) to be quite small.

# %%
simulator = pybop.pybamm.Simulator(
    model, parameter_values=parameter_values, protocol=dataset
)
cost = pybop.SumSquaredError(dataset)
problem = pybop.Problem(simulator, cost)
options = pybop.PintsOptions(max_iterations=100)
optim = pybop.GradientDescent(problem, options=options)
optim.optimiser.set_learning_rate(eta=0.01)
# Out:
# NOTE: Boundaries ignored by <class 'pybop.optimisers._gradient_descent.GradientDescentImpl'>

# %% [markdown]
# We proceed to run the optimiser with the updated learning rate. After the optimisation, we can examine the estimated parameter values. In this case, the optimised values differ from the ground truth values.

# %%
result = optim.run()

print("True values:", true_values)
print("Estimates:", result.x)
# Out:
# True values: [0.65, 0.51]
# Estimates: [0.61779841 0.5457801 ]

# %% [markdown]
# ## Calibrating the learning rate
#
# Now that we've seen how an unsuitable `eta` value prevents the optimiser from converging within the maximum number of iterations, let's calibrate this value to find the optimal solution using fewer iterations.

# %%
etas = np.linspace(0.02, 0.42, 3)
results = []
for eta in etas:
    optim = pybop.GradientDescent(problem, options=options)
    optim.optimiser.set_learning_rate(eta)
    result = optim.run()
    results.append(result)

for result, eta in zip(results, etas, strict=False):
    print(
        f"| eta: {eta} | Num Iterations: {result.n_iterations} | Best Cost: {result.best_cost} | Results: {result.x} |"
    )
# Out:
# NOTE: Boundaries ignored by <class 'pybop.optimisers._gradient_descent.GradientDescentImpl'>
# NOTE: Boundaries ignored by <class 'pybop.optimisers._gradient_descent.GradientDescentImpl'>
# NOTE: Boundaries ignored by <class 'pybop.optimisers._gradient_descent.GradientDescentImpl'>
# | eta: 0.02 | Num Iterations: 100 | Best Cost: 0.00148834298963961 | Results: [0.63087175 0.53068887] |
# | eta: 0.21999999999999997 | Num Iterations: 36 | Best Cost: 0.0012809594064389588 | Results: [0.6493396  0.51153732] |
# | eta: 0.42 | Num Iterations: 19 | Best Cost: 0.0015287449704297902 | Results: [0.64197256 0.52952851] |

# %% [markdown]
# From these results, we can see that `eta=0.22` returns the best cost value by balancing fast convergence with a small enough step size to avoid jumping over fine changes in the landscape.
#
# ### Cost landscapes
#
# Another way to view this information is to plot the optimiser trace on the cost landscape.

# %%
# Plot the cost landscape with optimisation path and updated bounds
bounds = np.array([[0.4, 0.8], [0.4, 0.8]])
for result, eta in zip(results, etas, strict=False):
    result.plot_surface(bounds=bounds, title=f"eta: {eta}")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="b6524a05-8a4d-4e06-9443-b7b2d3108a9c" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b6524a05-8a4d-4e06-9443-b7b2d3108a9c")) {                    Plotly.newPlot(                        "b6524a05-8a4d-4e06-9443-b7b2d3108a9c",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":{"dtype":"f8","bdata":"mpmZmZmZ2T8mcxBw67PZP7NMh0Y9ztk\u002fPyb+HI\u002fo2T\u002fM\u002f3Tz4ALaP1jZ68kyHdo\u002f5bJioIQ32j9xjNl21lHaP\u002f5lUE0obNo\u002fij\u002fHI3qG2j8WGT76y6DaP6PytNAdu9o\u002fL8wrp2\u002fV2j+8paJ9we\u002faP0h\u002fGVQTCts\u002f1ViQKmUk2z9hMgcBtz7bP+4LftcIWds\u002feuX0rVpz2z8Gv2uErI3bP5OY4lr+p9s\u002fH3JZMVDC2z+sS9AHotzbPzglR97z9ts\u002fxf69tEUR3D9R2DSLlyvcP96xq2HpRdw\u002faosiODtg3D\u002f2ZJkOjXrcP4M+EOXelNw\u002fDxiHuzCv3D+c8f2RgsncPyjLdGjU49w\u002ftaTrPib+3D9BfmIVeBjdP85X2evJMt0\u002fWjFQwhtN3T\u002fmCseYbWfdP3PkPW+\u002fgd0\u002f\u002f720RRGc3T+MlyscY7bdPxhxovK00N0\u002fpEoZyQbr3T8xJJCfWAXeP779BnaqH94\u002fStd9TPw53j\u002fWsPQiTlTeP2OKa\u002fmfbt4\u002f72Piz\u002fGI3j98PVmmQ6PePwgX0HyVvd4\u002flPBGU+fX3j8hyr0pOfLeP66jNACLDN8\u002fOn2r1twm3z\u002fGViKtLkHfP1MwmYOAW98\u002f3wkQWtJ13z9s44YwJJDfP\u002fi8\u002fQZ2qt8\u002fhJZ03cfE3z8RcOuzGd\u002ffP51JYopr+d8\u002flZFssN4J4D9b\u002fqebBxfgPyFr44YwJOA\u002f6Nceclkx4D+uRFpdgj7gP3SxlUirS+A\u002fOh7RM9RY4D8Aiwwf\u002fWXgP8f3Rwomc+A\u002fjWSD9U6A4D9T0b7gd43gPxk++sugmuA\u002f4Ko1t8mn4D+mF3Gi8rTgP2yErI0bwuA\u002fMvHneETP4D\u002f4XSNkbdzgP7\u002fKXk+W6eA\u002fhTeaOr\u002f24D9LpNUl6APhPxEREREREeE\u002f2H1M\u002fDke4T+e6ofnYivhP2RXw9KLOOE\u002fKsT+vbRF4T\u002fwMDqp3VLhP7eddZQGYOE\u002ffQqxfy9t4T9Dd+xqWHrhPwnkJ1aBh+E\u002f0FBjQaqU4T+WvZ4s06HhP1wq2hf8ruE\u002fIpcVAyW84T\u002foA1HuTcnhP69wjNl21uE\u002fdd3HxJ\u002fj4T87SgOwyPDhPwG3Ppvx\u002feE\u002fyCN6hhoL4j+OkLVxQxjiP1T98FxsJeI\u002fGmosSJUy4j\u002fg1mczvj\u002fiP6ZDox7nTOI\u002fbbDeCRBa4j8zHRr1OGfiP\u002fmJVeBhdOI\u002fwPaQy4qB4j+GY8y2s47iP0zQB6Lcm+I\u002fEj1DjQWp4j\u002fYqX54LrbiP54WumNXw+I\u002fZYP1ToDQ4j8r8DA6qd3iP\u002fFcbCXS6uI\u002fuMmnEPv34j9+NuP7IwXjP0SjHudMEuM\u002fChBa0nUf4z\u002fQfJW9nizjP5bp0KjHOeM\u002fXVYMlPBG4z8jw0d\u002fGVTjP+kvg2pCYeM\u002fsJy+VWtu4z92CfpAlHvjPzx2NSy9iOM\u002fAuNwF+aV4z\u002fIT6wCD6PjP4685+03sOM\u002fVSkj2WC94z8bll7EicrjP+ECmq+y1+M\u002fqG\u002fVmtvk4z9u3BCGBPLjPzRJTHEt\u002f+M\u002f+rWHXFYM5D\u002fAIsNHfxnkP4aP\u002fjKoJuQ\u002fTfw5HtEz5D8TaXUJ+kDkP9nVsPQiTuQ\u002foELs30tb5D9mryfLdGjkPywcY7addeQ\u002f8oieocaC5D+49dmM74\u002fkP35iFXgYneQ\u002fRc9QY0Gq5D8LPIxOarfkP9GoxzmTxOQ\u002fmBUDJbzR5D9egj4Q5d7kPyTvefsN7OQ\u002f6lu15jb55D+wyPDRXwblP3Y1LL2IE+U\u002fPaJnqLEg5T8DD6OT2i3lP8l73n4DO+U\u002fkOgZaixI5T9WVVVVVVXlPxzCkEB+YuU\u002f4i7MK6dv5T+omwcX0HzlP24IQwL5ieU\u002fNHV+7SGX5T\u002f74bnYSqTlP8FO9cNzseU\u002fiLswr5y+5T9OKGyaxcvlPxSVp4Xu2OU\u002f2gHjcBfm5T+gbh5cQPPlP2bbWUdpAOY\u002fLEiVMpIN5j\u002fztNAduxrmP7khDAnkJ+Y\u002fgI5H9Aw15j9G+4LfNULmPwxovspeT+Y\u002f0tT5tYdc5j+YQTWhsGnmP16ucIzZduY\u002fJBusdwKE5j\u002frh+diK5HmP7H0Ik5UnuY\u002feGFeOX2r5j8+zpkkprjmPwQ71Q\u002fPxeY\u002fyqcQ+\u002ffS5j+QFEzmIODmP1aBh9FJ7eY\u002fHO7CvHL65j\u002fjWv6nmwfnP6nHOZPEFOc\u002fcDR1fu0h5z82obBpFi\u002fnP\u002fwN7FQ\u002fPOc\u002fwnonQGhJ5z+I52IrkVbnP05Unha6Y+c\u002fFMHZAeNw5z\u002fbLRXtC37nP6GaUNg0i+c\u002faAeMw12Y5z8udMeuhqXnP\u002fTgApqvsuc\u002fuk0+hdi\u002f5z+AunlwAc3nP0YntVsq2uc\u002fDJTwRlPn5z\u002fTACwyfPTnP5ltZx2lAeg\u002fYNqiCM4O6D8mR97z9hvoP+yzGd8fKeg\u002fsiBVykg26D94jZC1cUPoPz76y6CaUOg\u002 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="cac8ee2c-0b7c-4b9a-bbfd-349a049a9765" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cac8ee2c-0b7c-4b9a-bbfd-349a049a9765")) {                    Plotly.newPlot(                        "cac8ee2c-0b7c-4b9a-bbfd-349a049a9765",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":{"dtype":"f8","bdata":"mpmZmZmZ2T8mcxBw67PZP7NMh0Y9ztk\u002fPyb+HI\u002fo2T\u002fM\u002f3Tz4ALaP1jZ68kyHdo\u002f5bJioIQ32j9xjNl21lHaP\u002f5lUE0obNo\u002fij\u002fHI3qG2j8WGT76y6DaP6PytNAdu9o\u002fL8wrp2\u002fV2j+8paJ9we\u002faP0h\u002fGVQTCts\u002f1ViQKmUk2z9hMgcBtz7bP+4LftcIWds\u002feuX0rVpz2z8Gv2uErI3bP5OY4lr+p9s\u002fH3JZMVDC2z+sS9AHotzbPzglR97z9ts\u002fxf69tEUR3D9R2DSLlyvcP96xq2HpRdw\u002faosiODtg3D\u002f2ZJkOjXrcP4M+EOXelNw\u002fDxiHuzCv3D+c8f2RgsncPyjLdGjU49w\u002ftaTrPib+3D9BfmIVeBjdP85X2evJMt0\u002fWjFQwhtN3T\u002fmCseYbWfdP3PkPW+\u002fgd0\u002f\u002f720RRGc3T+MlyscY7bdPxhxovK00N0\u002fpEoZyQbr3T8xJJCfWAXeP779BnaqH94\u002fStd9TPw53j\u002fWsPQiTlTeP2OKa\u002fmfbt4\u002f72Piz\u002fGI3j98PVmmQ6PePwgX0HyVvd4\u002flPBGU+fX3j8hyr0pOfLeP66jNACLDN8\u002fOn2r1twm3z\u002fGViKtLkHfP1MwmYOAW98\u002f3wkQWtJ13z9s44YwJJDfP\u002fi8\u002fQZ2qt8\u002fhJZ03cfE3z8RcOuzGd\u002ffP51JYopr+d8\u002flZFssN4J4D9b\u002fqebBxfgPyFr44YwJOA\u002f6Nceclkx4D+uRFpdgj7gP3SxlUirS+A\u002fOh7RM9RY4D8Aiwwf\u002fWXgP8f3Rwomc+A\u002fjWSD9U6A4D9T0b7gd43gPxk++sugmuA\u002f4Ko1t8mn4D+mF3Gi8rTgP2yErI0bwuA\u002fMvHneETP4D\u002f4XSNkbdzgP7\u002fKXk+W6eA\u002fhTeaOr\u002f24D9LpNUl6APhPxEREREREeE\u002f2H1M\u002fDke4T+e6ofnYivhP2RXw9KLOOE\u002fKsT+vbRF4T\u002fwMDqp3VLhP7eddZQGYOE\u002ffQqxfy9t4T9Dd+xqWHrhPwnkJ1aBh+E\u002f0FBjQaqU4T+WvZ4s06HhP1wq2hf8ruE\u002fIpcVAyW84T\u002foA1HuTcnhP69wjNl21uE\u002fdd3HxJ\u002fj4T87SgOwyPDhPwG3Ppvx\u002feE\u002fyCN6hhoL4j+OkLVxQxjiP1T98FxsJeI\u002fGmosSJUy4j\u002fg1mczvj\u002fiP6ZDox7nTOI\u002fbbDeCRBa4j8zHRr1OGfiP\u002fmJVeBhdOI\u002fwPaQy4qB4j+GY8y2s47iP0zQB6Lcm+I\u002fEj1DjQWp4j\u002fYqX54LrbiP54WumNXw+I\u002fZYP1ToDQ4j8r8DA6qd3iP\u002fFcbCXS6uI\u002fuMmnEPv34j9+NuP7IwXjP0SjHudMEuM\u002fChBa0nUf4z\u002fQfJW9nizjP5bp0KjHOeM\u002fXVYMlPBG4z8jw0d\u002fGVTjP+kvg2pCYeM\u002fsJy+VWtu4z92CfpAlHvjPzx2NSy9iOM\u002fAuNwF+aV4z\u002fIT6wCD6PjP4685+03sOM\u002fVSkj2WC94z8bll7EicrjP+ECmq+y1+M\u002fqG\u002fVmtvk4z9u3BCGBPLjPzRJTHEt\u002f+M\u002f+rWHXFYM5D\u002fAIsNHfxnkP4aP\u002fjKoJuQ\u002fTfw5HtEz5D8TaXUJ+kDkP9nVsPQiTuQ\u002foELs30tb5D9mryfLdGjkPywcY7addeQ\u002f8oieocaC5D+49dmM74\u002fkP35iFXgYneQ\u002fRc9QY0Gq5D8LPIxOarfkP9GoxzmTxOQ\u002fmBUDJbzR5D9egj4Q5d7kPyTvefsN7OQ\u002f6lu15jb55D+wyPDRXwblP3Y1LL2IE+U\u002fPaJnqLEg5T8DD6OT2i3lP8l73n4DO+U\u002fkOgZaixI5T9WVVVVVVXlPxzCkEB+YuU\u002f4i7MK6dv5T+omwcX0HzlP24IQwL5ieU\u002fNHV+7SGX5T\u002f74bnYSqTlP8FO9cNzseU\u002fiLswr5y+5T9OKGyaxcvlPxSVp4Xu2OU\u002f2gHjcBfm5T+gbh5cQPPlP2bbWUdpAOY\u002fLEiVMpIN5j\u002fztNAduxrmP7khDAnkJ+Y\u002fgI5H9Aw15j9G+4LfNULmPwxovspeT+Y\u002f0tT5tYdc5j+YQTWhsGnmP16ucIzZduY\u002fJBusdwKE5j\u002frh+diK5HmP7H0Ik5UnuY\u002feGFeOX2r5j8+zpkkprjmPwQ71Q\u002fPxeY\u002fyqcQ+\u002ffS5j+QFEzmIODmP1aBh9FJ7eY\u002fHO7CvHL65j\u002fjWv6nmwfnP6nHOZPEFOc\u002fcDR1fu0h5z82obBpFi\u002fnP\u002fwN7FQ\u002fPOc\u002fwnonQGhJ5z+I52IrkVbnP05Unha6Y+c\u002fFMHZAeNw5z\u002fbLRXtC37nP6GaUNg0i+c\u002faAeMw12Y5z8udMeuhqXnP\u002fTgApqvsuc\u002fuk0+hdi\u002f5z+AunlwAc3nP0YntVsq2uc\u002fDJTwRlPn5z\u002fTACwyfPTnP5ltZx2lAeg\u002fYNqiCM4O6D8mR97z9hvoP+yzGd8fKeg\u002fsiBVykg26D94jZC1cUPoPz76y6CaUOg\u002 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="77e17384-4bb0-4dbb-a4f7-c3736e3f1fc7" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("77e17384-4bb0-4dbb-a4f7-c3736e3f1fc7")) {                    Plotly.newPlot(                        "77e17384-4bb0-4dbb-a4f7-c3736e3f1fc7",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":{"dtype":"f8","bdata":"mpmZmZmZ2T8mcxBw67PZP7NMh0Y9ztk\u002fPyb+HI\u002fo2T\u002fM\u002f3Tz4ALaP1jZ68kyHdo\u002f5bJioIQ32j9xjNl21lHaP\u002f5lUE0obNo\u002fij\u002fHI3qG2j8WGT76y6DaP6PytNAdu9o\u002fL8wrp2\u002fV2j+8paJ9we\u002faP0h\u002fGVQTCts\u002f1ViQKmUk2z9hMgcBtz7bP+4LftcIWds\u002feuX0rVpz2z8Gv2uErI3bP5OY4lr+p9s\u002fH3JZMVDC2z+sS9AHotzbPzglR97z9ts\u002fxf69tEUR3D9R2DSLlyvcP96xq2HpRdw\u002faosiODtg3D\u002f2ZJkOjXrcP4M+EOXelNw\u002fDxiHuzCv3D+c8f2RgsncPyjLdGjU49w\u002ftaTrPib+3D9BfmIVeBjdP85X2evJMt0\u002fWjFQwhtN3T\u002fmCseYbWfdP3PkPW+\u002fgd0\u002f\u002f720RRGc3T+MlyscY7bdPxhxovK00N0\u002fpEoZyQbr3T8xJJCfWAXeP779BnaqH94\u002fStd9TPw53j\u002fWsPQiTlTeP2OKa\u002fmfbt4\u002f72Piz\u002fGI3j98PVmmQ6PePwgX0HyVvd4\u002flPBGU+fX3j8hyr0pOfLeP66jNACLDN8\u002fOn2r1twm3z\u002fGViKtLkHfP1MwmYOAW98\u002f3wkQWtJ13z9s44YwJJDfP\u002fi8\u002fQZ2qt8\u002fhJZ03cfE3z8RcOuzGd\u002ffP51JYopr+d8\u002flZFssN4J4D9b\u002fqebBxfgPyFr44YwJOA\u002f6Nceclkx4D+uRFpdgj7gP3SxlUirS+A\u002fOh7RM9RY4D8Aiwwf\u002fWXgP8f3Rwomc+A\u002fjWSD9U6A4D9T0b7gd43gPxk++sugmuA\u002f4Ko1t8mn4D+mF3Gi8rTgP2yErI0bwuA\u002fMvHneETP4D\u002f4XSNkbdzgP7\u002fKXk+W6eA\u002fhTeaOr\u002f24D9LpNUl6APhPxEREREREeE\u002f2H1M\u002fDke4T+e6ofnYivhP2RXw9KLOOE\u002fKsT+vbRF4T\u002fwMDqp3VLhP7eddZQGYOE\u002ffQqxfy9t4T9Dd+xqWHrhPwnkJ1aBh+E\u002f0FBjQaqU4T+WvZ4s06HhP1wq2hf8ruE\u002fIpcVAyW84T\u002foA1HuTcnhP69wjNl21uE\u002fdd3HxJ\u002fj4T87SgOwyPDhPwG3Ppvx\u002feE\u002fyCN6hhoL4j+OkLVxQxjiP1T98FxsJeI\u002fGmosSJUy4j\u002fg1mczvj\u002fiP6ZDox7nTOI\u002fbbDeCRBa4j8zHRr1OGfiP\u002fmJVeBhdOI\u002fwPaQy4qB4j+GY8y2s47iP0zQB6Lcm+I\u002fEj1DjQWp4j\u002fYqX54LrbiP54WumNXw+I\u002fZYP1ToDQ4j8r8DA6qd3iP\u002fFcbCXS6uI\u002fuMmnEPv34j9+NuP7IwXjP0SjHudMEuM\u002fChBa0nUf4z\u002fQfJW9nizjP5bp0KjHOeM\u002fXVYMlPBG4z8jw0d\u002fGVTjP+kvg2pCYeM\u002fsJy+VWtu4z92CfpAlHvjPzx2NSy9iOM\u002fAuNwF+aV4z\u002fIT6wCD6PjP4685+03sOM\u002fVSkj2WC94z8bll7EicrjP+ECmq+y1+M\u002fqG\u002fVmtvk4z9u3BCGBPLjPzRJTHEt\u002f+M\u002f+rWHXFYM5D\u002fAIsNHfxnkP4aP\u002fjKoJuQ\u002fTfw5HtEz5D8TaXUJ+kDkP9nVsPQiTuQ\u002foELs30tb5D9mryfLdGjkPywcY7addeQ\u002f8oieocaC5D+49dmM74\u002fkP35iFXgYneQ\u002fRc9QY0Gq5D8LPIxOarfkP9GoxzmTxOQ\u002fmBUDJbzR5D9egj4Q5d7kPyTvefsN7OQ\u002f6lu15jb55D+wyPDRXwblP3Y1LL2IE+U\u002fPaJnqLEg5T8DD6OT2i3lP8l73n4DO+U\u002fkOgZaixI5T9WVVVVVVXlPxzCkEB+YuU\u002f4i7MK6dv5T+omwcX0HzlP24IQwL5ieU\u002fNHV+7SGX5T\u002f74bnYSqTlP8FO9cNzseU\u002fiLswr5y+5T9OKGyaxcvlPxSVp4Xu2OU\u002f2gHjcBfm5T+gbh5cQPPlP2bbWUdpAOY\u002fLEiVMpIN5j\u002fztNAduxrmP7khDAnkJ+Y\u002fgI5H9Aw15j9G+4LfNULmPwxovspeT+Y\u002f0tT5tYdc5j+YQTWhsGnmP16ucIzZduY\u002fJBusdwKE5j\u002frh+diK5HmP7H0Ik5UnuY\u002feGFeOX2r5j8+zpkkprjmPwQ71Q\u002fPxeY\u002fyqcQ+\u002ffS5j+QFEzmIODmP1aBh9FJ7eY\u002fHO7CvHL65j\u002fjWv6nmwfnP6nHOZPEFOc\u002fcDR1fu0h5z82obBpFi\u002fnP\u002fwN7FQ\u002fPOc\u002fwnonQGhJ5z+I52IrkVbnP05Unha6Y+c\u002fFMHZAeNw5z\u002fbLRXtC37nP6GaUNg0i+c\u002faAeMw12Y5z8udMeuhqXnP\u002fTgApqvsuc\u002fuk0+hdi\u002f5z+AunlwAc3nP0YntVsq2uc\u002fDJTwRlPn5z\u002fTACwyfPTnP5ltZx2lAeg\u002fYNqiCM4O6D8mR97z9hvoP+yzGd8fKeg\u002fsiBVykg26D94jZC1cUPoPz76y6CaUOg\u002 ...

# %% [markdown]
# ### Optimised time-series trajectory
#
# Let's take `eta = 0.22` as the best learning rate for this problem and look at the time-series trajectory.

# %%
pybop.plot.problem(
    problem, inputs=results[2].best_inputs, title="Optimised Comparison"
);
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="e9d07214-de9b-4ba4-b0c4-d89cec5206ee" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e9d07214-de9b-4ba4-b0c4-d89cec5206ee")) {                    Plotly.newPlot(                        "e9d07214-de9b-4ba4-b0c4-d89cec5206ee",                        [{"fill":"toself","fillcolor":"rgba(255,229,204,0.8)","hoverinfo":"skip","line":{"color":"rgba(255,255,255,0)"},"showlegend":false,"x":[0.0,5.0,10.0,15.0,20.0,25.0,30.0,35.0,40.0,45.0,50.0,55.0,60.0,65.0,70.0,75.0,80.0,85.0,90.0,95.0,100.0,105.0,110.0,115.0,120.0,125.0,130.0,135.0,140.0,145.0,150.0,155.0,160.0,165.0,170.0,175.0,180.0,185.0,190.0,195.0,200.0,205.0,210.0,215.0,220.0,225.0,230.0,235.0,240.0,245.0,250.0,255.0,260.0,265.0,270.0,275.0,280.0,285.0,290.0,295.0,300.0,305.0,310.0,315.0,320.0,325.0,330.0,335.0,340.0,345.0,350.0,355.0,360.0,360.00000000000006,365.0,370.0,375.0,380.0,385.0,390.0,395.0,400.0,405.0,410.0,415.0,420.0,425.0,430.0,435.0,440.0,445.0,450.0,455.0,460.0,465.0,470.0,475.0,480.0,485.0,490.0,495.0,500.0,505.0,510.0,515.0,520.0,525.0,530.0,535.0,540.0,545.0,550.0,555.0,560.0,565.0,570.0,575.0,580.0,585.0,590.0,595.0,600.0,605.0,610.0,615.0,620.0,625.0,630.0,635.0,640.0,645.0,650.0,655.0,660.0,665.0,670.0,675.0,680.0,685.0,690.0,695.0,700.0,705.0,710.0,715.0,720.0,720.0000000000001,725.0,730.0,735.0,740.0,745.0,750.0,755.0,760.0,765.0,770.0,775.0,780.0,785.0,790.0,795.0,800.0,805.0,810.0,815.0,820.0,825.0,830.0,835.0,840.0,845.0,850.0,855.0,860.0,865.0,870.0,875.0,880.0,885.0,890.0,895.0,900.0,905.0,910.0,915.0,920.0,925.0,930.0,935.0,940.0,945.0,950.0,955.0,960.0,965.0,970.0,975.0,980.0,985.0,990.0,995.0,1000.0,1005.0,1010.0,1015.0,1020.0,1025.0,1030.0,1035.0,1040.0,1045.0,1050.0,1055.0,1060.0,1065.0,1070.0,1075.0,1080.0,1080.0000000000002,1085.0,1090.0,1095.0,1100.0,1105.0,1110.0,1115.0,1120.0,1125.0,1130.0,1135.0,1140.0,1145.0,1150.0,1155.0,1160.0,1165.0,1170.0,1175.0,1180.0,1185.0,1190.0,1195.0,1200.0,1205.0,1210.0,1215.0,1220.0,1225.0,1230.0,1235.0,1240.0,1245.0,1250.0,1255.0,1260.0,1265.0,1270.0,1275.0,1280.0,1285.0,1290.0,1295.0,1300.0,1305.0,1310.0,1315.0,1320.0,1325.0,1330.0,1335.0,1340.0,1345.0,1350.0,1355.0,1360.0,1365.0,1370.0,1375.0,1380.0,1385.0,1390.0,1395.0,1400.0,1405.0,1410.0,1415.0,1420.0,1425.0,1430.0,1435.0,1440.0,1440.0,1435.0,1430.0,1425.0,1420.0,1415.0,1410.0,1405.0,1400.0,1395.0,1390.0,1385.0,1380.0,1375.0,1370.0,1365.0,1360.0,1355.0,1350.0,1345.0,1340.0,1335.0,1330.0,1325.0,1320.0,1315.0,1310.0,1305.0,1300.0,1295.0,1290.0,1285.0,1280.0,1275.0,1270.0,1265.0,1260.0,1255.0,1250.0,1245.0,1240.0,1235.0,1230.0,1225.0,1220.0,1215.0,1210.0,1205.0,1200.0,1195.0,1190.0,1185.0,1180.0,1175.0,1170.0,1165.0,1160.0,1155.0,1150.0,1145.0,1140.0,1135.0,1130.0,1125.0,1120.0,1115.0,1110.0,1105.0,1100.0,1095.0,1090.0,1085.0,1080.0000000000002,1080.0,1075.0,1070.0,1065.0,1060.0,1055.0,1050.0,1045.0,1040.0,1035.0,1030.0,1025.0,1020.0,1015.0,1010.0,1005.0,1000.0,995.0,990.0,985.0,980.0,975.0,970.0,965.0,960.0,955.0,950.0,945.0,940.0,935.0,930.0,925.0,920.0,915.0,910.0,905.0,900.0,895.0,890.0,885.0,880.0,875.0,870.0,865.0,860.0,855.0,850.0,845.0,840.0,835.0,830.0,825.0,820.0,815.0,810.0,805.0,800.0,795.0,790.0,785.0,780.0,775.0,770.0,765.0,760.0,755.0,750.0,745.0,740.0,735.0,730.0,725.0,720.0000000000001,720.0,715.0,710.0,705.0,700.0,695.0,690.0,685.0,680.0,675.0,670.0,665.0,660.0,655.0,650.0,645.0,640.0,635.0,630.0,625.0,620.0,615.0,610.0,605.0,600.0,595.0,590.0,585.0,580.0,575.0,570.0,565.0,560.0,555.0,550.0,545.0,540.0,535.0,530.0,525.0,520.0,515.0,510.0,505.0,500.0,495.0,490.0,485.0,480.0,475.0,470.0,465.0,460.0,455.0,450.0,445.0,440.0,435.0,430.0,425.0,420.0,415.0,410.0,405.0,400.0, ...

# %% [markdown]
# ## Concluding thoughts
#
# This notebook covers how to calibrate the learning rate for the gradient descent optimiser, thus providing an introduction to hyperparameter tuning.
#
# We have shown how a small learning rate impedes the optimiser by imposing a small step size that requires many iterations to traverse the search space. A larger learning rate can provide the best performance, but too large a learning rate can cause the gradient descent algorithm to diverge (as shown in the last cost landscape plot).
