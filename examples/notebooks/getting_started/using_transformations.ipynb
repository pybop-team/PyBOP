# %% [markdown]
# # Introduction to Transformations
# This example introduces the `pybop.BaseTransformation` class and its instances. This class enables the cost and likelihood functions to be evaluated in a transformed, search space. The search space is used by the optimiser and sampler classes during inference. These transformations can be both linear (e.g. `pybop.ScaledTransformation`) and non-linear (e.g. `pybop.LogTransformation`). By default, if transformations are applied, the sampling and optimisers will search in the transformed space.
#
# Transformations can be helpful when the difference in parameter magnitudes is large, or to create a search space that is better posed for the optimisation algorithm.
#
# ### Setting up the Environment
#
# If you don't already have PyBOP installed, check out the [installation guide](https://pybop-docs.readthedocs.io/en/latest/installation.html) first.
#
# We begin by importing the necessary libraries. Let's also fix the random seed to generate consistent output during development.

# %%
import numpy as np
import pybamm

import pybop

pybop.plot.PlotlyManager().pio.renderers.default = "notebook_connected"

np.random.seed(8)  # users can remove this line

# %% [markdown]
# First, to showcase the transformation functionality, we need to construct an optimisation problem. This class is typically built on the following objects:
# - Model
# - Dataset
# - Parameters to identify
# - Cost function
#
# We will first construct the model, then the parameters and corresponding dataset. Once that is complete, the problem will be created with which we will showcase the different interactions users can have with transformations.

# %%
model = pybamm.lithium_ion.SPM()

# %% [markdown]
# Now that we have the model constructed, let's define the parameters for identification. At this point, we define the transformations applied to each parameter. PyBOP allows for transformations to be applied at the individual parameter level, which are then combined for application during the optimisation.
#
# ## Linear transformation
#
# Below we apply a linear transformation using the `pybop.ScaledTransformation` class. This class has arguments for a `coefficient` which defines the linear stretch or scaling of the search space, and `intercept` which defines the translation or shift. The equation for this transformation is:
#
# $$
# y_{search} = m(x_{model}+b)
# $$
#
# where $m$ is the linear scale coefficient, $b$ is the intercept, $x_{model}$ is the model parameter space, and $y_{search}$ is the transformed space.

# %%
parameters = [
    pybop.Parameter(
        "Negative electrode active material volume fraction",
        initial_value=0.6,
        bounds=[0.35, 0.7],
        transformation=pybop.ScaledTransformation(
            coefficient=1 / 0.35, intercept=-0.35, n_parameters=1
        ),
    ),
    pybop.Parameter(
        "Positive electrode active material volume fraction",
        initial_value=0.6,
        bounds=[0.45, 0.625],
        transformation=pybop.ScaledTransformation(
            coefficient=1 / 0.175, intercept=-0.45, n_parameters=1
        ),
    ),
]

# %% [markdown]
# Next, to create the `pybop.Dataset` we generate some synthetic data from the model using a `pybamm.Simulation`.

# %%
t_eval = np.linspace(0, 10, 100)
sim = pybamm.Simulation(model)
sol = sim.solve(t_eval=t_eval)

dataset = pybop.Dataset(
    {
        "Time [s]": t_eval,
        "Current function [A]": sol["Current [A]"](t_eval),
        "Voltage [V]": sol["Voltage [V]"](t_eval),
    }
)

# %% [markdown]
# Now that we have the model, parameters, and dataset, we can combine them and construct the problem class with a cost function.

# %%
builder = (
    pybop.builders.Pybamm()
    .set_dataset(dataset)
    .set_simulation(model)
    .add_cost(pybop.costs.pybamm.SumOfPower("Voltage [V]", "Voltage [V]"))
)
for param in parameters:
    builder.add_parameter(param)

problem = builder.build()

# %% [markdown]
# To evaluate the cost, we pass parameter values in the original (untransformed) model space.

# %%
problem.set_params([0.6, 0.6])
cost_value = problem.run()
print("Cost:", cost_value)
# Out:
# Cost: [0.00690259]

# %% [markdown]
# Now we can set up and run the optimisation process, which will apply the transformations internally.

# %%
options = pybop.ScipyMinimizeOptions(maxiter=50)
optim = pybop.SciPyMinimize(problem, options=options)
results = optim.run()

# %% [markdown]
# To see the effect of transformation, we can compare the cost landscapes plotted in the model and search spaces. Let's first plot the cost in the model space through the conventional method:

# %%
pybop.plot.contour(optim);
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="9122b7a9-67d6-4362-9c2c-6df02724802f" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9122b7a9-67d6-4362-9c2c-6df02724802f")) {                    Plotly.newPlot(                        "9122b7a9-67d6-4362-9c2c-6df02724802f",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"connectgaps":false,"x":{"dtype":"f8","bdata":"ZmZmZmZm1j84juM4juPYPwu2YAu2YNs\u002f3t3d3d3d3T\u002fYgi3Ygi3gP8EWbMEWbOE\u002fqqqqqqqq4j+UPumTPunjP33SJ33SJ+U\u002fZmZmZmZm5j8="},"y":{"dtype":"f8","bdata":"zczMzMzM3D+2YAu2YAveP6D0SZ\u002f0Sd8\u002fRERERERE4D85juM4juPgPy7Ygi3YguE\u002fIiIiIiIi4j8XbMEWbMHiPwy2YAu2YOM\u002fAAAAAAAA5D8="},"z":{"dtype":"f8","bdata":"9CAWVm5YgD87snlG5j96Pz5rfhY8enU\u002fop64bHXZcT9MLsKS0Q9uP5cvw1jnmWk\u002fE37sKesDZj9664AXvxdjP8TgCJmWrmA\u002fWxDztBxYXT\u002fNGb6dz31zP7pkRmYwMm0\u002faK4PCDEzZj915Coi5RNhP91JI6G2gVo\u002fzhLWFRC0VD8UMhXNyz1QP54q\u002fVbQi0k\u002f+STYiygbRD\u002fokvgIbJ4\u002fP38XlegbOWQ\u002fS3vlIh6+Wj\u002f7eWVyG5VRP9O\u002fBEGzxEY\u002f3XOW7fuwPD8JpT3bd00xPyn4bTWGdiM\u002f7PRQCgx9Ez+pW+yt5GT\u002fPoy1+c2V1t0+D95oniwdUD+kcnTTvPA\u002fP+oiG4ERTys\u002fKNcVswLtED+g5IUd7mDcPgpL9NuSK9I+JIMpwgbHAz85b4goA7EYP\u002f0J99bNqSU\u002fil8x0WgTMD\u002fQyE+Q5ngpPxY4tPWh2fY+B3kUTaUp4z4sdV5d3iwXP6ibrRoo2Sw\u002f4jwyfr\u002fxOD9dxiSWCjVCP5mx0pTLIEg\u002fyfXBmYIOTj\u002f+9ujoIvFRP0A694emA+A+\u002fH52n5PHIj9aZ60yiC85PxSg\u002fNOyJkY\u002fF6RIcJswUD9JD4jU11xVP3HzjTqqcFo\u002fxa3nj8FWXz9LscCNLgJiP8awJHx6OmQ\u002fseDs1Bt5Nj\u002fDH0thpU9JPwjcwclgkVQ\u002f1m3+jHiqXD9yBiIhwUxiPwSIByE8GWY\u002fuyevHeKwaT\u002fM85FqkBFtP5WLoErOHHA\u002f+P4e8x6WcT\u002fjZ9bA8IZSPyIxusaMKV4\u002fyOKFMP7tZD8QczlVXJBqP0Cqd4GD4G8\u002faeKeHbBqcj+ndp8fTrd0P8Vd\u002fHUW2HY\u002f2yEr1PfPeD+V6trbNKJ6P6iW5\u002fqf7WI\u002fuJmv3Uvxaj+Q9egnzExxPyNPDTi533Q\u002fkqpYAHMseD+kG2klejR7P8U4chgo\u002fH0\u002fYckMZXBEgD\u002fK1jdCGXCBP13O82e2g4I\u002fJ0W\u002f8MFfbz8hm4XQvL50P868rTZYcHk\u002fyllPqrO8fT939rNZetOAP\u002fISwnI6m4I\u002fyEUM0H85hD8+ao4Ne7OFP32ti3nIDIc\u002fuKt\u002f3QpJiD8=","shape":"10, 10"},"type":"contour"}],                        {"height":600,"legend":{"orientation":"h","x":1,"xanchor":"right","y":1,"yanchor":"bottom"},"title":{"text":"Cost Landscape","x":0.5,"y":0.905},"width":600,"xaxis":{"exponentformat":"e","range":[0.35,0.7],"showexponent":"last","title":{"text":"Negative electrode active material volume fraction"}},"yaxis":{"exponentformat":"e","range":[0.45,0.625],"showexponent":"last","title":{"text":"Positive electrode active material volume fraction"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[ ...

# %% [markdown]
# Next, we can use the `apply_transform` argument when constructing the cost landscape to plot in the transformed space.

# %%
pybop.plot.contour(optim, apply_transform=True);
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="17eb8ea3-44dc-41e0-93d9-cbce35592b8a" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("17eb8ea3-44dc-41e0-93d9-cbce35592b8a")) {                    Plotly.newPlot(                        "17eb8ea3-44dc-41e0-93d9-cbce35592b8a",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"connectgaps":false,"x":{"dtype":"f8","bdata":"AAAAAAAAAACXJEmSJEmyP5EkSZIkScI\u002f3bZt27Ztyz+RJEmSJEnSP7dt27Zt29Y\u002f3bZt27Zt2z\u002f9\u002f\u002f\u002f\u002f\u002f\u002f\u002ffP5EkSZIkSeI\u002fJEmSJEmS5D+3bdu2bdvmP0qSJEmSJOk\u002f2rZt27Zt6z9t27Zt27btPwAAAAAAAPA\u002f"},"y":{"dtype":"f8","bdata":"AAAAAAAAAACXJEmSJEmyP5ckSZIkScI\u002f17Zt27Ztyz+RJEmSJEnSP7Ft27Zt29Y\u002f3bZt27Zt2z\u002f9\u002f\u002f\u002f\u002f\u002f\u002f\u002ffP5QkSZIkSeI\u002fJEmSJEmS5D+0bdu2bdvmP0qSJEmSJOk\u002f2rZt27Zt6z9w27Zt27btPwAAAAAAAPA\u002f"},"z":{"dtype":"f8","bdata":"9CAWVm5YgD8EoMacrFJ8PzJJ1mlTvng\u002fDhH1BYjGdT9ARHgW90lzP0+04nasL3E\u002fo1VeR1zJbj\u002fAMljws7RrPw77MGKFCmk\u002fLrbIu8O4Zj+4OXY1B7FkPxaCP5q052I\u002fISUJDl1TYT8n7cQMjNhfP1sQ87QcWF0\u002fOx1I3r28dz9GE3PE0Al0PwTm8ljzC3E\u002fpiqJYNUybT8His8+WydpP4Voe1kAyGU\u002ffMxp0mPyYj9B7aKUKoxgP4nQavq9AV0\u002fSLIBouGAWT+N1hbWQ3xWP9uAVut731M\u002fjZLiig2aUT\u002fHgoWmGD1PP939hQnrw0s\u002fQhXpDzhycD9TZN1tc8lqP7vr3cRx8GU\u002fczZcodMMYj\u002fusbnj1M1dP5R+nNsPq1g\u002fYGTodn5zVD+ZxWY8CvhQP+Y2yMLNKEw\u002f6aZJh5lYRz8fTAyr6VJDP3819fKu6D8\u002fmz04GQdBOj9b10ktBoE1P\u002fqdYYligzE\u002fzUz\u002f2zxVZT9nTd7qE3pgP6LWbfIwdFk\u002fXm1ZMq2eUz9sAHh6Vh1OPwG+nw4x9EY\u002f9wKH1ZBTQT+Y+OdfUNA5P2xerqWj5DI\u002fAPv715cDKz\u002fE\u002fyNvObYiP95F8IUF0Rg\u002fMYqtE\u002fnqDj9SbSlgyYEBPz1OWxDY4PA+Y3OXX08MWT+oxDolt8BRP9yJYxzQwEg\u002fZaG45qbYQD8efVmTbyY2P8fyzr+csSs\u002fOiZCWxgLID9afPAZWWwQPy4Fl7votvo+goo4Hiyo2D5U\u002fmTWU1oNPj5zse\u002f3WNQ+1i2fGQH48j6OeZ7hpNsDPxk1o95BcxA\u002fyxcM09LgSD\u002fEf2KMp+49PzV7LgwypjA\u002fs+CcbYI7ID+LkOwBJocIP921AdoQzuI+arxw2+0akj7NyEuKCL7rPi5XlQpqKwY\u002fkpKdgbrTFT9jBscI2G4hP1mnYCf\u002fyCg\u002fXyoV6DpdMD+fSq0b14k0P+cN9CwA2Dg\u002f8RzRzAWTMT\u002f54rXneD8bP5Q8Sz6m3Pc+sorow9Z4gz5q6ZSCZ\u002fLzPrqijPdSoxE\u002f4lu87KTbIT\u002fAZW6GP8ksPxWVlNEzgDQ\u002fVB\u002fElvQHOz86ufA+DulAP9NgEyPiX0Q\u002fqzt0lAbdRz+YsC\u002fICVhLP1HbyZG3yk4\u002fb1DJs+Y+AD8oVECeMkWpPmwHkxcEjgM\u002f7cQFKhguHz8lJVux1z8uP1vdqgn4wDc\u002fTn9SsjyaQD\u002feFHdrBZJFP330tfgsqUo\u002fv+6CdOvJTz+Y0JhlaXJSPweFqX6E91Q\u002fhZ7iPYNwVz8qAcfn19pZP2cCbpHXNFw\u002f\u002fn1O\u002fnqJ+j55Yfyjj2EgP3BMRT3kEDI\u002fDUyuBnsKPj+58+HdgqNFP\u002fL3sIdkmkw\u002fKoZXvxTcUT8+cPIMcW1VP74Hp4TB9Vg\u002fqbGnVEttXD8AjB+G\u002fM5fP777\u002f3vRi2E\u002fbhBFyK8iYz\u002f2RL5coatkP4mbS8GCJmY\u002f6IqTciA\u002fLj\u002fs9rl\u002f0+k9P3YZETrChUc\u002fB5gKJoVcUD+Vy+R6WxpVP+WAHr7O3lk\u002ftfPZl4aWXj8CKDqNhJphP10zxytB2WM\u002fcTxZLiQFZj9RCuf87BxoPzoFoWcXIGo\u002fxN6s9J4ObD83UUm21OhtP8E6nttBr28\u002fWayJB8SaRD\u002f\u002fTn5u3wBQP\u002fyvV+78C1Y\u002f733t4bw0XD9+3GsACCxhP5yS5Pf4LWQ\u002f5iIqge0ZZz82cVHg1utpPzz\u002fjzqWoWw\u002f0ZatnFM6bz93o5KiBttwP25quuulCnI\u002fT5BFi3cscz9+dTiNBUF0P1ZRAFroSHU\u002f3j7l7KW0Uz\u002fM2hUlVlpbP5Qi\u002fSqajWE\u002fRQThT81jZT+NM3fNpSFpP3ud7oaZvmw\u002fKhtB+jMbcD+VPG4QkMNxP5S0hGIwWHM\u002fg2M43GHZdD+KJPZUvkd2Pz2XxZEMpHc\u002f92JMNSvveD8+EJTuAip6P4KFYH59VXs\u002fkM94GBS7Xz+1NAdzRKJkP99xwOk8V2k\u002fAkeHCabpbT+uo\u002f\u002fYqydxP0g1tUlvQXM\u002f1goVLENBdT\u002fe9IQoNid3Px2iiAXw83g\u002f\u002fATDSXGoej+wWXcX6kV8P3MLYeufzX0\u002f860D\u002ftxAfz81wBb2clCAPzKqir1594A\u002fMZ10aRATZz80x2YJ28JsP0CyjVAvI3E\u002f ...

# %% [markdown]
# Note the difference in axis scale compared to the non-transformed landscape
#
# ## Log transformation
#
# Next, let's change the transformation on the "Positive electrode active material volume fraction" to a non-linear, log transformation.

# %%
old_param = parameters[1]
parameters[1] = pybop.Parameter(
    "Positive electrode active material volume fraction",
    initial_value=old_param.initial_value,
    bounds=old_param.bounds,
    transformation=pybop.LogTransformation(),
)

builder = (
    pybop.builders.Pybamm()
    .set_dataset(dataset)
    .set_simulation(model)
    .add_cost(pybop.costs.pybamm.SumOfPower("Voltage [V]", "Voltage [V]"))
)
for param in parameters:
    builder.add_parameter(param)

problem = builder.build()

# %% [markdown]
# Let's plot the cost landscape again. This time, the values on the y-axis are negative as they correspond to the log of the model values.

# %%
pybop.plot.contour(problem, apply_transform=True);
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="3f799c20-9c7d-4466-a4cc-e7e7951f0b90" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3f799c20-9c7d-4466-a4cc-e7e7951f0b90")) {                    Plotly.newPlot(                        "3f799c20-9c7d-4466-a4cc-e7e7951f0b90",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"connectgaps":false,"x":{"dtype":"f8","bdata":"AAAAAAAAAACXJEmSJEmyP5EkSZIkScI\u002f3bZt27Ztyz+RJEmSJEnSP7dt27Zt29Y\u002f3bZt27Zt2z\u002f9\u002f\u002f\u002f\u002f\u002f\u002f\u002ffP5EkSZIkSeI\u002fJEmSJEmS5D+3bdu2bdvmP0qSJEmSJOk\u002f2rZt27Zt6z9t27Zt27btPwAAAAAAAPA\u002f"},"y":{"dtype":"f8","bdata":"AAAAAAAAAACXJEmSJEmyP5ckSZIkScI\u002f17Zt27Ztyz+RJEmSJEnSP7Ft27Zt29Y\u002f3bZt27Zt2z\u002f9\u002f\u002f\u002f\u002f\u002f\u002f\u002ffP5QkSZIkSeI\u002fJEmSJEmS5D+0bdu2bdvmP0qSJEmSJOk\u002f2rZt27Zt6z9w27Zt27btPwAAAAAAAPA\u002f"},"z":{"dtype":"f8","bdata":"9CAWVm5YgD8EoMacrFJ8PzJJ1mlTvng\u002fDhH1BYjGdT9ARHgW90lzP0+04nasL3E\u002fo1VeR1zJbj\u002fAMljws7RrPw77MGKFCmk\u002fLrbIu8O4Zj+4OXY1B7FkPxaCP5q052I\u002fISUJDl1TYT8n7cQMjNhfP1sQ87QcWF0\u002fOx1I3r28dz9GE3PE0Al0PwTm8ljzC3E\u002fpiqJYNUybT8His8+WydpP4Voe1kAyGU\u002ffMxp0mPyYj9B7aKUKoxgP4nQavq9AV0\u002fSLIBouGAWT+N1hbWQ3xWP9uAVut731M\u002fjZLiig2aUT\u002fHgoWmGD1PP939hQnrw0s\u002fQhXpDzhycD9TZN1tc8lqP7vr3cRx8GU\u002fczZcodMMYj\u002fusbnj1M1dP5R+nNsPq1g\u002fYGTodn5zVD+ZxWY8CvhQP+Y2yMLNKEw\u002f6aZJh5lYRz8fTAyr6VJDP3819fKu6D8\u002fmz04GQdBOj9b10ktBoE1P\u002fqdYYligzE\u002fzUz\u002f2zxVZT9nTd7qE3pgP6LWbfIwdFk\u002fXm1ZMq2eUz9sAHh6Vh1OPwG+nw4x9EY\u002f9wKH1ZBTQT+Y+OdfUNA5P2xerqWj5DI\u002fAPv715cDKz\u002fE\u002fyNvObYiP95F8IUF0Rg\u002fMYqtE\u002fnqDj9SbSlgyYEBPz1OWxDY4PA+Y3OXX08MWT+oxDolt8BRP9yJYxzQwEg\u002fZaG45qbYQD8efVmTbyY2P8fyzr+csSs\u002fOiZCWxgLID9afPAZWWwQPy4Fl7votvo+goo4Hiyo2D5U\u002fmTWU1oNPj5zse\u002f3WNQ+1i2fGQH48j6OeZ7hpNsDPxk1o95BcxA\u002fyxcM09LgSD\u002fEf2KMp+49PzV7LgwypjA\u002fs+CcbYI7ID+LkOwBJocIP921AdoQzuI+arxw2+0akj7NyEuKCL7rPi5XlQpqKwY\u002fkpKdgbrTFT9jBscI2G4hP1mnYCf\u002fyCg\u002fXyoV6DpdMD+fSq0b14k0P+cN9CwA2Dg\u002f8RzRzAWTMT\u002f54rXneD8bP5Q8Sz6m3Pc+sorow9Z4gz5q6ZSCZ\u002fLzPrqijPdSoxE\u002f4lu87KTbIT\u002fAZW6GP8ksPxWVlNEzgDQ\u002fVB\u002fElvQHOz86ufA+DulAP9NgEyPiX0Q\u002fqzt0lAbdRz+YsC\u002fICVhLP1HbyZG3yk4\u002fb1DJs+Y+AD8oVECeMkWpPmwHkxcEjgM\u002f7cQFKhguHz8lJVux1z8uP1vdqgn4wDc\u002fTn9SsjyaQD\u002feFHdrBZJFP330tfgsqUo\u002fv+6CdOvJTz+Y0JhlaXJSPweFqX6E91Q\u002fhZ7iPYNwVz8qAcfn19pZP2cCbpHXNFw\u002f\u002fn1O\u002fnqJ+j55Yfyjj2EgP3BMRT3kEDI\u002fDUyuBnsKPj+58+HdgqNFP\u002fL3sIdkmkw\u002fKoZXvxTcUT8+cPIMcW1VP74Hp4TB9Vg\u002fqbGnVEttXD8AjB+G\u002fM5fP777\u002f3vRi2E\u002fbhBFyK8iYz\u002f2RL5coatkP4mbS8GCJmY\u002f6IqTciA\u002fLj\u002fs9rl\u002f0+k9P3YZETrChUc\u002fB5gKJoVcUD+Vy+R6WxpVP+WAHr7O3lk\u002ftfPZl4aWXj8CKDqNhJphP10zxytB2WM\u002fcTxZLiQFZj9RCuf87BxoPzoFoWcXIGo\u002fxN6s9J4ObD83UUm21OhtP8E6nttBr28\u002fWayJB8SaRD\u002f\u002fTn5u3wBQP\u002fyvV+78C1Y\u002f733t4bw0XD9+3GsACCxhP5yS5Pf4LWQ\u002f5iIqge0ZZz82cVHg1utpPzz\u002fjzqWoWw\u002f0ZatnFM6bz93o5KiBttwP25quuulCnI\u002fT5BFi3cscz9+dTiNBUF0P1ZRAFroSHU\u002f3j7l7KW0Uz\u002fM2hUlVlpbP5Qi\u002fSqajWE\u002fRQThT81jZT+NM3fNpSFpP3ud7oaZvmw\u002fKhtB+jMbcD+VPG4QkMNxP5S0hGIwWHM\u002fg2M43GHZdD+KJPZUvkd2Pz2XxZEMpHc\u002f92JMNSvveD8+EJTuAip6P4KFYH59VXs\u002fkM94GBS7Xz+1NAdzRKJkP99xwOk8V2k\u002fAkeHCabpbT+uo\u002f\u002fYqydxP0g1tUlvQXM\u002f1goVLENBdT\u002fe9IQoNid3Px2iiAXw83g\u002f\u002fATDSXGoej+wWXcX6kV8P3MLYeufzX0\u002f860D\u002ftxAfz81wBb2clCAPzKqir1594A\u002fMZ10aRATZz80x2YJ28JsP0CyjVAvI3E\u002f ...

# %% [markdown]
# ## Concluding thoughts
#
# In this notebook, we've introduced the transformation class and its interaction with the parameters. Transformations allow the optimisation or sampling search space to be transformed for improved convergence in situations where the optimisation hyperparameters are poorly tuned, or in optimisation tasks with high variance in the parameter magnitudes.
